# %%
import numpy as np
import pandas as pd
import pickle
import tweepy
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import os
from dotenv import load_dotenv
load_dotenv() 
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
API_Key = os.environ.get("API_Key")
API_Key_Secret = os.environ.get("API_Key_Secret")
Bearer_Token = os.environ.get("Bearer_Token")
Access_Token = os.environ.get("Access_Token")
Access_Token_Secret = os.environ.get("Access_Token_Secret")

# %%
API_Key
# Out:
# 'LuijDxfZZU5jbQScO1Zwf7L2u'

# %%
def createDatasets():
    # Change the path according to your system configuration
    path = r"C:/Users/afs18/Downloads/"
    real_folders = ['data/2017/real_accounts1.csv', 'data/2015/real_accounts2.csv', 'data/2015/real_accounts3.csv']
    bot_folders = ['data/2017/bots1.csv',
                         'data/2017/bots2.csv',
                         'data/2017/bots3.csv',
                         'data/2017/bots4.csv']
    real_users_list = []
    real_tweet_list = []  
    for folder in real_folders:
        df_users = pd.read_csv(path + folder+"/users.csv",index_col="id", encoding="latin-1", low_memory=False);
        df_users["source_f"] = folder; 
        real_users_list.append(df_users);
        df_tweets = pd.read_csv(path + folder+"/tweets.csv",index_col="id", encoding="latin-1", low_memory=False);
        df_tweets["source_f"] = folder; 
        real_tweet_list.append(df_tweets);
    real_tweets = pd.concat(real_tweet_list)
    real_users = pd.concat(real_users_list)

    bot_users_list = []
    bot_tweets_list = []
    for folder in bot_folders:
        df_users = pd.read_csv(path + folder+"/users.csv",index_col="id", encoding="latin-1", low_memory=False);
        df_users["source_f"] = folder;
        bot_users_list.append(df_users);    
        df_tweets = pd.read_csv(path + folder+"/tweets.csv",index_col="id", encoding="latin-1", low_memory=False);
        df_tweets["source_f"] = folder;
        bot_tweets_list.append(df_tweets);
    bot_tweets = pd.concat(bot_tweets_list)
    bot_users = pd.concat(bot_users_list)

    users = pd.concat([bot_users,real_users])
    tweets = pd.concat([bot_tweets,real_tweets])

    user_class = pd.concat([pd.DataFrame(np.ones(shape=(len(bot_users),1))),pd.DataFrame(np.zeros(shape=(len(real_users),1)))])
    user_class.rename(columns={0:"is_bot"},inplace=True);

    # Remove users with no tweets
    user_class = user_class[users.index.isin(tweets.set_index("user_id").index)]
    users = users[users.index.isin(tweets.set_index("user_id").index)]
    
    del users["following"];
    del tweets["contributors"];
    del users["notifications"];
    del tweets["favorited"];
    del tweets["geo"];
    del users["contributors_enabled"];
    del users["follow_request_sent"];    
    del users["test_set_1"];
    del users["test_set_2"];
    del tweets["retweeted"];
    
    # Change timestamp into datetime
    tweets["timestamp_dt"] = pd.to_datetime(tweets["timestamp"],format='%Y-%m-%d %H:%M:%S')
    del tweets["timestamp"]

    return users, user_class, tweets

# %%
users, user_class, tweets = createDatasets()

# %%
users
# Out:
#                                name     screen_name  statuses_count  \
# id
# 24858289             Davide Bertoli       davideb66            1299
# 33212890             Elisa D'Ospina    ElisaDospina           18665
# 39773427            Donato Vincenzo      Vladimir65           22987
# 57007623         Rafiela Morales L.  RafielaMorales            7975
# 63258466          Â§ h a â  u râ     FabrizioC_c           20218
# ...                             ...             ...             ...
# 1127280169         Frilaif Official         frilaif              49
# 1156344000  ââ¥HeartsQueenâ¥â    Stronzetta__              66
# 1169114810            angelagervasi  angelagervasi2               4
# 1212975186                 Midnight         Movie1O               3
# 1213937306                 Ê¸áµáµ  xjawaadscookie            2568
#
#             followers_count  friends_count  favourites_count  listed_count  \
# id
# 24858289                 22             40                 1             0
# 33212890              12561           3442             16358           110
# 39773427                600            755                14             6
# 57007623                398            350                11             2
# 63258466                413            405               162             8
# ...                     ...            ...               ...           ...
# 1127280169              208            124                14             2
# 1156344000               22             55                 0             0
# 1169114810                0              4                 3             0
# 1212975186                2              4                 0             0
# 1213937306              351            341               318             2
#
#                                url lang                   time_zone  ...  \
# id                                                                   ...
# 24858289                       NaN   it                        Rome  ...
# 33212890    http://t.co/ceK8TovxwI   it                   Greenland  ...
# 39773427                       NaN   it                        Rome  ...
# 57007623                       NaN   en  Pacific Time (US & Canada)  ...
# 63258466    http://t.co/PK5F0JDKcy   it                        Rome  ...
# ...                            ...  ...                         ...  ...
# 1127280169  http://t.co/IkqfPF32pr   it                         NaN  ...
# 1156344000                     NaN   it                         NaN  ...
# 1169114810                     NaN   it                         NaN  ...
# 1212975186                     NaN   it                         NaN  ...
# 1213937306                     NaN   it                   Amsterdam  ...
#
#            is_translator  protected  verified  \
# id
# 24858289             NaN        NaN       NaN
# 33212890             NaN        NaN       NaN
# 39773427             NaN        NaN       NaN
# 57007623             NaN        NaN       NaN
# 63258466             NaN        NaN       NaN
# ...                  ...        ...       ...
# 1127280169           NaN        NaN       NaN
# 1156344000           NaN        NaN       NaN
# 1169114810           NaN        NaN       NaN
# 1212975186           NaN        NaN       NaN
# 1213937306           NaN        NaN       NaN
#
#                                                   description  \
# id
# 24858289                                                  NaN
# 33212890    Autrice del libro #unavitatuttacurve dal 9 apr...
# 39773427                              [Live Long and Prosper]
# 57007623    Cuasi Odontologa*â¥,#Bipolar, #Sarcastica & S...
# 63258466    I shall rise from my own death, to avenge hers...
# ...                                                       ...
# 1127280169  Sex and Erotic Advisor. Sexual health is a sta...
# 1156344000  Se avessi seguito tutte le regole non sarei ma...
# 1169114810  mamma e giovane nonna,laureata,amante del teat...
# 1212975186  If you don't shut your fucking mouth, I will k...
# 1213937306  @onedirection I JUST WANNA SAY A MASSIVE THANK...
#
#                                 created_at            timestamp  \
# id
# 24858289    Tue Mar 17 08:51:12 +0000 2009  2009-03-17 09:51:12
# 33212890    Sun Apr 19 14:38:04 +0000 2009  2009-04-19 16:38:04
# 39773427    Wed May 13 15:34:41 +0000 2009  2009-05-13 17:34:41
# 57007623    Wed Jul 15 12:55:03 +0000 2009  2009-07-15 14:55:03
# 63258466    Wed Aug 05 21:12:49 +0000 2009  2009-08-05 23:12:49
# ...                                    ...                  ...
# 1127280169  Mon Jan 28 07:13:47 +0000 2013                  NaN
# 1156344000  Thu Feb 07 07:27:08 +0000 2013                  NaN
# 1169114810  Mon Feb 11 14:50:19 +0000 2013                  NaN
# 1212975186  Sat Feb 23 17:46:55 +0000 2013                  NaN
# 1213937306  Sat Feb 23 23:17:08 +0000 2013                  NaN
#
#                      crawled_at              updated  \
# id
# 24858289    2014-04-19 14:46:19  2016-03-15 14:12:22
# 33212890    2014-05-18 23:20:58  2016-03-15 14:17:13
# 39773427    2014-05-13 23:21:54  2016-03-15 14:16:44
# 57007623    2014-05-19 23:24:18  2016-03-15 14:18:54
# 63258466    2014-05-11 23:22:23  2016-03-15 14:17:05
# ...                         ...                  ...
# 1127280169                  NaN  2015-02-14 10:54:49
# 1156344000                  NaN  2015-02-14 10:54:49
# 1169114810                  NaN  2015-02-14 10:54:49
# 1212975186                  NaN  2015-02-14 10:54:49
# 1213937306                  NaN  2015-02-14 10:54:49
#
#                                 source_f dataset
# id
# 24858289             data/2017/bots1.csv     NaN
# 33212890             data/2017/bots1.csv     NaN
# 39773427             data/2017/bots1.csv     NaN
# 57007623             data/2017/bots1.csv     NaN
# 63258466             data/2017/bots1.csv     NaN
# ...                                  ...     ...
# 1127280169  data/2015/real_accounts3.csv     E13
# 1156344000  data/2015/real_accounts3.csv     E13
# 1169114810  data/2015/real_accounts3.csv     E13
# 1212975186  data/2015/real_accounts3.csv     E13
# 1213937306  data/2015/real_accounts3.csv     E13
#
# [8941 rows x 37 columns]

# %%
def featureEngineering(users, tweets):
    # Add a new feature which is the ratio of friends count to followers counts
    users.loc[:,"friend_follower_ratio"] = users["friends_count"] / (users["followers_count"] + 1)
    
    
    # Get the average of the tweets features corresponding to every user
    average_tweets = tweets[["num_hashtags", "retweet_count", "favorite_count", "num_mentions", "num_urls", "user_id"]].groupby("user_id").mean()
    
    # Replace missing values with 0
    average_tweets = average_tweets.fillna(0)
    
    # Add _per_tweet to the features names
    users = users.join(average_tweets.add_suffix("_per_tweet"))
    
    users.loc[:,"unique_tweet_place"] = tweets.groupby("user_id").place.nunique()
    
    # Add a new feature which is the variance of user's tweets per hour
    tweets.loc[:,"date"] = tweets.timestamp_dt.dt.date
    tweets.loc[:,"hour"] = tweets.timestamp_dt.dt.hour
    variance_tweet_rate = tweets.groupby(["user_id", "date", "hour"]).size().groupby("user_id").var()
    variance_tweet_rate.rename("variance_in_tweet_rate", inplace=True)
    users = users.join(variance_tweet_rate)
    
    return users, tweets

# %%
users, tweets = featureEngineering(users, tweets)

# %%
users
# Out:
#                                name     screen_name  statuses_count  \
# id
# 24858289             Davide Bertoli       davideb66            1299
# 33212890             Elisa D'Ospina    ElisaDospina           18665
# 39773427            Donato Vincenzo      Vladimir65           22987
# 57007623         Rafiela Morales L.  RafielaMorales            7975
# 63258466          Â§ h a â  u râ     FabrizioC_c           20218
# ...                             ...             ...             ...
# 1127280169         Frilaif Official         frilaif              49
# 1156344000  ââ¥HeartsQueenâ¥â    Stronzetta__              66
# 1169114810            angelagervasi  angelagervasi2               4
# 1212975186                 Midnight         Movie1O               3
# 1213937306                 Ê¸áµáµ  xjawaadscookie            2568
#
#             followers_count  friends_count  favourites_count  listed_count  \
# id
# 24858289                 22             40                 1             0
# 33212890              12561           3442             16358           110
# 39773427                600            755                14             6
# 57007623                398            350                11             2
# 63258466                413            405               162             8
# ...                     ...            ...               ...           ...
# 1127280169              208            124                14             2
# 1156344000               22             55                 0             0
# 1169114810                0              4                 3             0
# 1212975186                2              4                 0             0
# 1213937306              351            341               318             2
#
#                                url lang                   time_zone  \
# id
# 24858289                       NaN   it                        Rome
# 33212890    http://t.co/ceK8TovxwI   it                   Greenland
# 39773427                       NaN   it                        Rome
# 57007623                       NaN   en  Pacific Time (US & Canada)
# 63258466    http://t.co/PK5F0JDKcy   it                        Rome
# ...                            ...  ...                         ...
# 1127280169  http://t.co/IkqfPF32pr   it                         NaN
# 1156344000                     NaN   it                         NaN
# 1169114810                     NaN   it                         NaN
# 1212975186                     NaN   it                         NaN
# 1213937306                     NaN   it                   Amsterdam
#
#                                location  default_profile  \
# id
# 24858289                            NaN              1.0
# 33212890                          Italy              NaN
# 39773427     iPhone: 45.471680,9.192429              NaN
# 57007623    ÃT: 18.4698712,-69.9327525              NaN
# 63258466                        Firenze              NaN
# ...                                 ...              ...
# 1127280169              World Wide Mind              1.0
# 1156344000                          NaN              NaN
# 1169114810                          NaN              1.0
# 1212975186                          NaN              NaN
# 1213937306          oned || ddlovato ||              NaN
#
#             default_profile_image  geo_enabled  \
# id
# 24858289                      1.0          1.0
# 33212890                      NaN          1.0
# 39773427                      NaN          NaN
# 57007623                      NaN          NaN
# 63258466                      NaN          1.0
# ...                           ...          ...
# 1127280169                    NaN          NaN
# 1156344000                    NaN          NaN
# 1169114810                    1.0          NaN
# 1212975186                    NaN          NaN
# 1213937306                    NaN          1.0
#
#                                                                                      profile_image_url  \
# id
# 24858289               http://abs.twimg.com/sticky/default_profile_images/default_profile_1_normal.png
# 33212890                               http://pbs.twimg.com/profile_images/2603147033/image_normal.jpg
# 39773427               http://pbs.twimg.com/profile_images/2290354446/641uwgq40y8ehltoeyka_normal.jpeg
# 57007623                   http://pbs.twimg.com/profile_images/378800000857236581/JTbHVA5U_normal.jpeg
# 63258466                   http://pbs.twimg.com/profile_images/463301942291492864/L3LQ-1DI_normal.jpeg
# ...                                                                                                ...
# 1127280169  http://a0.twimg.com/profile_images/3173608915/b19e1368bb4e7b63ebb17fe881e0b819_normal.jpeg
# 1156344000  http://a0.twimg.com/profile_images/3219394294/07576d89afdf15a784caff7f1e3aadb8_normal.jpeg
# 1169114810              http://a0.twimg.com/sticky/default_profile_images/default_profile_3_normal.png
# 1212975186  http://a0.twimg.com/profile_images/3410781890/63ac7b870d12844ecf21f0755423c7de_normal.jpeg
# 1213937306   http://a0.twimg.com/profile_images/3354404569/6673abfd712a61f43e0c53e8f0e88426_normal.png
#
#                                                      profile_banner_url  \
# id
# 24858289                                                            NaN
# 33212890      https://pbs.twimg.com/profile_banners/33212890/1397039982
# 39773427      https://pbs.twimg.com/profile_banners/39773427/1366657159
# 57007623      https://pbs.twimg.com/profile_banners/57007623/1357079488
# 63258466      https://pbs.twimg.com/profile_banners/63258466/1399725401
# ...                                                                 ...
# 1127280169  https://si0.twimg.com/profile_banners/1127280169/1359357768
# 1156344000  https://si0.twimg.com/profile_banners/1156344000/1360223209
# 1169114810                                                          NaN
# 1212975186  https://si0.twimg.com/profile_banners/1212975186/1363898227
# 1213937306  https://si0.twimg.com/profile_banners/1213937306/1362770695
#
#             profile_use_background_image  \
# id
# 24858289                             1.0
# 33212890                             1.0
# 39773427                             1.0
# 57007623                             1.0
# 63258466                             1.0
# 1213937306                     DDEEF6
#
#                                                                               profile_background_image_url  \
# id
# 24858289                                                  http://abs.twimg.com/images/themes/theme1/bg.png
# 33212890                   http://pbs.twimg.com/profile_background_images/453844878657482752/6a3GomzA.jpeg
# 39773427    http://pbs.twimg.com/profile_background_images/849790938/8e4083c4d34d59e4c09ccb3e51afdc9e.jpeg
# 57007623                http://pbs.twimg.com/profile_background_images/576667469/507rsfgju9s91hjeu3ic.jpeg
# 63258466                 http://pbs.twimg.com/profile_background_images/220859199/twitter-background-6.jpg
# ...                                                                                                    ...
# 1127280169                                                 http://a0.twimg.com/images/themes/theme1/bg.png
# 1156344000                                                http://a0.twimg.com/images/themes/theme10/bg.gif
# 1169114810                                                 http://a0.twimg.com/images/themes/theme1/bg.png
# 1212975186   http://a0.twimg.com/profile_background_images/820511186/12b64e6d70cf5e2bb7916de2f85f09ec.jpeg
# 1213937306   http://a0.twimg.com/profile_background_images/809583367/ef1c11a25567abed88c073f95defd6be.jpeg
#
#            profile_background_color profile_link_color  utc_offset  \
# id
# 24858289                     C0DEED             0084B4      7200.0
# 33212890                     EBEBEB             990000     -7200.0
# 39773427                     131516             009999      7200.0
# 57007623                     E60584             4BC90C    -25200.0
# 63258466                     EBEBEB             000000      7200.0
# ...                             ...                ...         ...
# 1127280169                   C0DEED             0084B4         NaN
# 1156344000                   642D8B             740CC4         NaN
# 1169114810                   C0DEED             0084B4         NaN
# 1212975186                   FFFFFF             000000         NaN
# 1213937306                   FFFFFF             2BF00C      3600.0
#
#             is_translator  protected  verified  \
# id
# 24858289              NaN        NaN       NaN
# 33212890              NaN        NaN       NaN
# 39773427              NaN        NaN       NaN
# 57007623              NaN        NaN       NaN
# 63258466              NaN        NaN       NaN
# ...                   ...        ...       ...
# 1127280169            NaN        NaN       NaN
# 1156344000            NaN        NaN       NaN
# 1169114810            NaN        NaN       NaN
# 1212975186            NaN        NaN       NaN
# 1213937306            NaN        NaN       NaN
#
#                                                                                                                                                             description  \
# id
# 24858289                                                                                                                                                            NaN
# 33212890                         Autrice del libro #unavitatuttacurve dal 9 aprile in tutte le librerie.Top model #curvy, su @Raidue tutor di #moda per @dettofattorai2
# 39773427                                                                                                                                        [Live Long and Prosper]
# 57007623        Cuasi Odontologa*â¥,#Bipolar, #Sarcastica & Some might say im a BiTch but I'm just a Free beast in a Wild life.- #1God'sFan, Dreamer & Music Believer~
# 63258466                                                                                I shall rise from my own death, to avenge hers with all the powers of darkness.
# ...                                                                                                                                                                 ...
# 1127280169  Sex and Erotic Advisor. Sexual health is a state of physical, mental and social well-being in relation to sexuality. Be curious, not judgmental. W. Whitman
# 1156344000                                                                                      Se avessi seguito tutte le regole non sarei mai arrivata fin qui.... ;)
# 1169114810                                                                                              mamma e giovane nonna,laureata,amante del teatro e della poesia
# 1212975186                                                                                                       If you don't shut your fucking mouth, I will kill you.
# 1213937306                                                                                                          @onedirection I JUST WANNA SAY A MASSIVE THANK YOU.
#
#                                 created_at            timestamp  \
# id
# 24858289    Tue Mar 17 08:51:12 +0000 2009  2009-03-17 09:51:12
# 1127280169            0.456522                   0               64.666667
# 1156344000            0.000000                   0                0.185714
# 1169114810            0.750000                   0                0.000000
# 1212975186            0.333333                   0                0.000000
# 1213937306            0.065599                   5              163.507801
#
# [8941 rows x 45 columns]

# %%
def featureSelection(users):
    final_df = users[['favourites_count','followers_count','friends_count','verified','friend_follower_ratio','num_hashtags_per_tweet','retweet_count_per_tweet','favorite_count_per_tweet','num_mentions_per_tweet','num_urls_per_tweet','unique_tweet_place','variance_in_tweet_rate']]
    values = {"verified":0, "variance_in_tweet_rate":0}
    final_df = final_df.fillna(value=values)
    return final_df

X = featureSelection(users)

# %%
def normalizeData(X, isTrain=True):
    if(isTrain):
        scaler = StandardScaler()
        scaler = scaler.fit(X)
        pickle.dump(scaler, open("Pickle/scaler.pickle", "wb"))
        X.loc[:,:] = scaler.transform(X)
    else:
        scaler = pickle.load(open("Pickle/scaler.pickle", "rb"))
        X.loc[:,:] = scaler.transform(X)
        
    return X
X = normalizeData(X)

# %%
X_train, X_val, y_train, y_val = train_test_split(X, user_class, test_size=0.2)

pickle.dump(X_train, open("Pickle/X_train.pickle", "wb"))
pickle.dump(X_val, open("Pickle/X_val.pickle", "wb"))
pickle.dump(y_train, open("Pickle/y_train.pickle", "wb"))
pickle.dump(y_val, open("Pickle/y_val.pickle", "wb"))

# %%
# client = tweepy.Client(
#     consumer_key= API_Key,
#     consumer_secret=API_Key_Secret,
#     access_token= Access_Token,
#     access_token_secret= Access_Token_Secret
# )

# %%
auth = tweepy.OAuthHandler(API_Key, API_Key_Secret)
auth.set_access_token(Access_Token, Access_Token_Secret)
api = tweepy.API(auth)

# %%
api.user_timeline(user_id=256597786)
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# <ipython-input-8-036ed8603327> in <module>
# ----> 1 api.user_timeline(user_id=256597786)
#
# c:\python\python385\lib\site-packages\tweepy\api.py in wrapper(*args, **kwargs)
#      31         @functools.wraps(method)
#      32         def wrapper(*args, **kwargs):
# ---> 33             return method(*args, **kwargs)
#      34         wrapper.pagination_mode = mode
#      35         return wrapper
#
# c:\python\python385\lib\site-packages\tweepy\api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# c:\python\python385\lib\site-packages\tweepy\api.py in user_timeline(self, **kwargs)
#     569         https://developer.twitter.com/en/docs/twitter-api/v1/tweets/timelines/api-reference/get-statuses-user_timeline
#     570         """
# --> 571         return self.request(
#     572             'GET', 'statuses/user_timeline', endpoint_parameters=(
#     573                 'user_id', 'screen_name', 'since_id', 'count', 'max_id',
#
# c:\python\python385\lib\site-packages\tweepy\api.py in request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     257                 raise Unauthorized(resp)
#     258             if resp.status_code == 403:
# --> 259                 raise Forbidden(resp)
#     260             if resp.status_code == 404:
#     261                 raise NotFound(resp)
#
# Forbidden: 403 Forbidden
# 453 - You currently have Essential access which includes access to Twitter API v2 endpoints only. If you need access to this endpoint, you’ll need to apply for Elevated access via the Developer Portal. You can learn more here: https://developer.twitter.com/en/docs/twitter-api/getting-started/about-twitter-api#v2-access-leve
